# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Q1.Load the flight price dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
flight_price = pd.read_excel('flight_price.xlsx')
flight_price.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
flight_price.shape
# Out:
# (10683, 11)

# %% [markdown]
# - it have 10683 rows
# - it have 11 columns

# %% [markdown]
# ### Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the distribution.

# %%
# plt.figure(figsize=(16,6))
sns.histplot(flight_price.Price,bins=30,kde=True)
# plt.show()
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %% [markdown]
# ***Price distribution seems to be right skewed***

# %% [markdown]
# ### Q3. What is the range of prices in the dataset? What is the minimum and maximum price?

# %%
flight_price['Price'].describe()
# Out:
# count    10683.000000
# mean      9087.064121
# std       4611.359167
# min       1759.000000
# 25%       5277.000000
# 50%       8372.000000
# 75%      12373.000000
# max      79512.000000
# Name: Price, dtype: float64

# %% [markdown]
# ***Min Price*** :- 1759
# ***Max Price*** :- 79512

# %% [markdown]
# ### Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different airlines.

# %%
plt.figure(figsize=(20,7))
sns.boxenplot(data=flight_price,x='Airline',y='Price')
plt.show()

# %% [markdown]
# Jet airways has the highest prices

# %%
plt.figure(figsize=(30,7))
sns.barplot(x=flight_price.Airline,y=flight_price.Price)
plt.show()

# %% [markdown]
# ### Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how they may impact your analysis.

# %%
plt.figure(figsize=(20,10))
sns.boxplot(flight_price)
plt.show()

# %% [markdown]
# - Yes there are outliers present in the price columns.It affects our model in price prediction scope as it disturbs the range of the price

# %% [markdown]
# ### Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset to identify the peak travel season. What features would you analyze to identify the peak season, and how would you present your findings to your boss?

# %% [markdown]
# I Will analyze the following features for the same:-
# - Departure Date
# - Route and Destination
# - Airline Information
# - Price fluctuations among different airlines
# - Weather conditions
#
# ### Presentation Structure:
#
# #### 1. **Introduction:**
#    - Briefly explain the purpose of the analysis: to identify the peak travel season based on flight price data.
#
# #### 2. **Data Overview:**
#    - Mention the dataset size and the timeframe it covers.
#    - Describe the key features you analyzed (departure date, destination, airline, etc.).
#
# #### 3. **Analysis and Findings:**
#    - **Monthly Analysis:**
#      - Present a line chart showing average flight prices over each month. Highlight peaks and troughs.
#      - Identify the months with consistently high prices as potential peak travel seasons.
#    - **Day of the Week Analysis:**
#      - Show a bar chart illustrating average prices on different days of the week.
#      - Identify specific days with notably higher or lower prices.
#    - **Route and Destination Analysis:**
#      - Present a heatmap or bar chart showing average prices for different routes and destinations.
#      - Identify popular routes and destinations with higher prices during specific periods.
#    - **Airline Analysis:**
#      - Display a bar chart comparing average prices across different airlines.
#      - Identify airlines with consistent high or low prices, indicating their pricing strategies.
#    - **Special Events and Holidays:**
#      - Highlight specific events, holidays, or festivals and show how flight prices vary during these periods.
#
# #### 4. **Conclusion:**
#    - Summarize the identified peak travel seasons based on the analysis.
#    - Provide recommendations for the travel agency, such as adjusting pricing strategies or offering promotions during off-peak seasons.
#
# #### 5. **Next Steps:**
#    - Suggest further analysis or data collection methods if needed.
#    - Discuss potential strategies for the travel agency to capitalize on peak seasons and optimize pricing during off-peak periods.
#
# Remember, the visualization of data through charts and graphs can significantly enhance the clarity of your findings.

# %% [markdown]
# ### Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight Price dataset to identify any trends in flight prices. What features would you analyze to identify these trends, and what visualizations would you use to present your findings to your team?

# %% [markdown]
# To identify trends in flight prices, I would like to analyze various features in the Flight Price dataset. Here are the key features you might consider analyzing and the corresponding visualizations to present your findings effectively:
#
# ### Features to Analyze:
#
# 1. **Date/Time Features:**
#    - **Departure Date:** Analyze how prices vary with different dates.
#    - **Month/Season:** Identify trends in prices across different months or seasons.
#    - **Day of the Week:** Check for price fluctuations based on specific days of the week.
#
# 2. **Route and Destination:**
#    - **Origin and Destination Cities:** Analyze price differences for different routes.
#    - **Specific Routes:** Investigate prices for specific routes.
#
# 3. **Airline Information:**
#    - **Airline:** Explore how prices differ among various airlines.
#    - **Flight Class:** Analyze price trends for economy, business, or first class.
#
# 4. **Other Relevant Factors:**
#    - **Duration of the Flight:** Check if flight duration correlates with prices.
#    - **Advance Booking Period:** Analyze if prices change based on how far in advance the ticket is booked.
#    - **Special Events or Holidays:** Investigate price trends during events, holidays, or festivals.
#
# ### Visualizations to Use:
#
# 1. **Line Charts:**
#    - Use line charts to show how average flight prices change over time (monthly, weekly) for overall trends.
#    - You can have separate lines for different airlines or routes to compare trends.
#
# 2. **Bar Charts:**
#    - Utilize bar charts to compare average prices across different airlines, routes, days of the week, or months.
#    - Use grouped or stacked bar charts to compare prices for different flight classes.
#
# 3. **Box Plots:**
#    - Use box plots to show the distribution of prices for different airlines, routes, or months.
#    - Box plots can reveal outliers and provide a good understanding of the price range.
#
# 4. **Heatmaps:**
#    - Create heatmaps to visualize average prices for different routes and months. Heatmaps can quickly show patterns and trends.
#
# 5. **Scatter Plots:**
#    - Use scatter plots to explore relationships between flight prices and factors like flight duration or advance booking period.
#    - Color the points based on different airlines or routes for better differentiation.
#
# 6. **Violin Plots:**
#    - Violin plots combine aspects of box plots and kernel density plots, providing a comprehensive view of price distributions.
#    - Use them to compare price distributions across different categories like airlines or flight classes.
#
# 7. **Time Series Analysis:**
#    - Use time series analysis techniques like moving averages or exponential smoothing to identify long-term trends and seasonality in flight prices.
#
# 8. **Correlation Matrix:**
#    - Create a correlation matrix to identify relationships between different features and flight prices. This can help you understand which factors influence prices the most.
#
# When presenting my findings to your team, consider creating a comprehensive report or presentation that includes these visualizations along with clear explanations. Focus on key insights, outliers, and any actionable recommendations based on the trends you identify. Visualizations should be labeled properly, and trends should be described in a clear and concise manner to ensure that the audience understands the significance of your findings.

# %% [markdown]
# ### Q8. You are a data scientist working for an airline company, and you have been asked to analyze the Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to identify these factors, and how would you present your findings to the management team?

# %% [markdown]
# To identify the factors that affect flight prices in the Flight Price dataset, you would need to conduct a thorough analysis of various features. Here are the key features you should analyze and the steps to present your findings to the management team:
#
# ### Features to Analyze:
#
# 1. **Date/Time Features:**
#    - **Departure Date and Time:** Analyze how flight prices vary based on different times of the day and days of the week.
#    - **Month/Season:** Identify any seasonal patterns in flight prices.
#    - **Advance Booking Period:** Explore how prices change based on how far in advance the ticket is booked.
#    - **Special Events or Holidays:** Analyze price trends during specific events or holiday periods.
#
# 2. **Route and Destination:**
#    - **Origin and Destination Cities:** Investigate price differences for different routes.
#    - **Specific Routes:** Analyze prices for specific routes within the airline's network.
#
# 3. **Airline Information:**
#    - **Airline:** Explore how prices differ among various airlines.
#    - **Flight Class:** Analyze price trends for different flight classes (economy, business, first class).
#
# 4. **Other Relevant Factors:**
#    - **Flight Duration:** Check if flight duration correlates with prices.
#    - **Number of Stops:** Analyze the impact of direct flights versus flights with layovers on prices.
#    - **Aircraft Type:** Investigate if different aircraft types have varying price structures.
#    - **Market Demand:** Explore how prices are affected by the demand for specific routes.
#
# ### Steps to Present Your Findings:
#
# 1. **Data Preparation and Cleaning:**
#    - Clean the dataset, handle missing values, and preprocess the features for analysis.
#
# 2. **Exploratory Data Analysis (EDA):**
#    - Generate summary statistics for key features.
#    - Create visualizations (scatter plots, box plots, histograms) to understand the distribution of prices and relationships with other variables.
#
# 3. **Feature Importance Analysis:**
#    - Use techniques like correlation analysis, feature importance from machine learning models, or statistical tests (ANOVA, t-tests) to identify features significantly affecting flight prices.
#
# 4. **Model Building and Analysis:**
#    - Build predictive models (such as regression models or machine learning algorithms) to quantify the impact of different features on flight prices.
#    - Analyze coefficients or feature importance scores from the models to understand the magnitude and direction of the influence of each feature.
#
# 5. **Key Findings and Insights:**
#    - Summarize the main factors affecting flight prices, highlighting the most influential features.
#    - Provide actionable insights, such as adjusting pricing strategies based on demand patterns, optimizing prices for specific routes, or offering promotions during low-demand periods.
#
# 6. **Visualization and Reporting:**
#    - Create visually appealing charts and graphs to present the findings. Use bar charts, heatmaps, and regression plots to illustrate the relationships.
#    - Prepare a detailed report or presentation outlining the methodology, key findings, and actionable recommendations.
#
# 7. **Actionable Recommendations:**
#    - Provide clear and actionable recommendations based on the analysis. For instance, suggest pricing adjustments for specific routes during peak seasons, offer discounts for early bookings, or optimize pricing strategies for different flight classes.
#
# 8. **Interactive Dashboards (Optional):**
#    - Consider creating interactive dashboards (using tools like Tableau or Power BI) that allow the management team to explore the data and findings dynamically.
#
# When presenting your findings to the management team, focus on clear communication, providing context for the data, and emphasizing the business implications of the analysis. Use visualizations effectively to make complex patterns and insights easily understandable.

# %% [markdown]
# # Google PlayStore

# %% [markdown]
# ### Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
gp = pd.read_csv('Google_playstore.csv')
gp.shape
# Out:
# (10841, 13)

# %% [markdown]
# - it has 10841 rows and 13 columns

# %% [markdown]
# ### Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different app categories.

# %%
gp.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
plt.figure(figsize=(40,17))
sns.boxplot(x=gp['Category'],y=gp['Rating'])
plt.show()

# %% [markdown]
# ### Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may impact your analysis.

# %%
gp.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# - there are 1474 missing values in rating column, 1 missing value in type column,8 missing in current ver and 3 values are missing from Android Ve column
#
# ***how affects***
# - Missing values reduce the effective sample size for analysis
# - it leads to unbiased analysis

# %% [markdown]
# ### Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize the relationship.

# %%
plt.figure(figsize=(20,6))
sns.scatterplot(x=gp['Size'],y=gp['Rating'])
plt.show()

# %% [markdown]
# - It can be observed that app with higher size have almost greater rating

# %% [markdown]
# ### Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.

# %%
gp.sample(5)
# Out:
#                                 App            Category  Rating Reviews  Size  \
# 6751                      Kiosko BS  NEWS_AND_MAGAZINES     NaN      55   22M
# 6942                        BX Memo              FAMILY     4.3     131  2.0M
# 5367                     I am Bread                GAME     4.0     630   20M
# 4708              Mental Hospital V                GAME     4.2    2460   25M
# 6960  Bitcoin & Cryptocurrency - Bx             FINANCE     4.8      11  3.7M
#
#      Installs  Type  Price Content Rating            Genres  \
# 6751   1,000+  Free      0       Everyone  News & Magazines
# 6942   5,000+  Free      0       Everyone         Education
# 5367  10,000+  Paid  $4.99       Everyone         Adventure
# 4708  50,000+  Paid  $0.99     Mature 17+            Action
# 6960   1,000+  Free      0       Everyone           Finance
#
#            Last Updated Current Ver Android Ver
# 6751       May 12, 2017         2.0  4.0 and up
# ...

# %%
gp = gp[gp['Price']!='Everyone']

# %%
gp.shape
# Out:
# (10840, 13)

# %%
gp['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
gp['Price_N'] = (gp['Price'].str.replace('$','')).astype(float)
# np.where(gp['Price'][0]=='$',gp['Price'].str.split('$')[1],gp['Price'])

# %%
plt.figure(figsize=(14,7))
sns.barplot(x=gp['Type'],y=gp['Price_N'])
plt.show()

# %% [markdown]
# ### Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps with the highest number of installs.

# %%
sorted_gp = gp.sort_values(by='Installs',ascending=False)

# %%
sorted_gp.reset_index(inplace=True)

# %%
sorted_gp.drop(columns=['level_0','index'],inplace=True)

# %%
sorted_gp
# Out:
#                                          App          Category  Rating  \
# 0                               Temple Run 2              GAME     4.3
# 1      Google Duo - High Quality Video Calls     COMMUNICATION     4.6
# 2                            Viber Messenger     COMMUNICATION     4.3
# 3                            Google Calendar      PRODUCTIVITY     4.2
# 4                                    Dropbox      PRODUCTIVITY     4.4
# ...                                      ...               ...     ...
# 10835               EG | Explore Folegandros  TRAVEL_AND_LOCAL     NaN
# 10836                          Pekalongan CJ            SOCIAL     NaN
# 10837                             CX Network          BUSINESS     NaN
# 10838      I'm Rich/Eu sou Rico/أنا غني/我很有錢         LIFESTYLE     NaN
# 10839              Command & Conquer: Rivals            FAMILY     NaN
#
#         Reviews                Size      Installs  Type    Price  \
# ...

# %% [markdown]
# - Top 10 most installed apps

# %%
sorted_gp.head(10)
# Out:
#                                      App            Category  Rating  \
# 0                           Temple Run 2                GAME     4.3
# 1  Google Duo - High Quality Video Calls       COMMUNICATION     4.6
# 2                        Viber Messenger       COMMUNICATION     4.3
# 3                        Google Calendar        PRODUCTIVITY     4.2
# 4                                Dropbox        PRODUCTIVITY     4.4
# 5                                Dropbox        PRODUCTIVITY     4.4
# 6                           Temple Run 2                GAME     4.3
# 7            LINE: Free Calls & Messages       COMMUNICATION     4.2
# 8                            Cloud Print        PRODUCTIVITY     4.1
# 9           Flipboard: News For Our Time  NEWS_AND_MAGAZINES     4.4
#
#     Reviews                Size      Installs  Type Price Content Rating  \
# 0   8118609                 62M  500,000,000+  Free     0       Everyone
# ...

# %%
# Creating a frequency table for the 'Category' column
frequency_table = pd.DataFrame({
    'App' : sorted_gp['App'],
    'No of Installs' : sorted_gp['Installs']
})

# Displaying the frequency table
frequency_table
# print(frequency_table)
# Out:
#                                          App No of Installs
# 0                               Temple Run 2   500,000,000+
# 1      Google Duo - High Quality Video Calls   500,000,000+
# 2                            Viber Messenger   500,000,000+
# 3                            Google Calendar   500,000,000+
# 4                                    Dropbox   500,000,000+
# ...                                      ...            ...
# 10835               EG | Explore Folegandros             0+
# 10836                          Pekalongan CJ             0+
# 10837                             CX Network             0+
# 10838      I'm Rich/Eu sou Rico/أنا غني/我很有錢             0+
# 10839              Command & Conquer: Rivals              0
#
# [10840 rows x 2 columns]

# %% [markdown]
# ### Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the Google Playstore dataset to identify the most popular app categories. How would you approach this task, and what features would you analyze to make recommendations to the company?

# %% [markdown]
# To identify the most popular app categories on the Google Play Store, you can approach the task through a series of steps involving data analysis. Here's a systematic approach to help you make recommendations to the company:
#
# ### 1. **Data Exploration:**
#    - **Load the Dataset:** Load the Google Play Store dataset into a Pandas DataFrame.
#    - **Explore the Data:** Understand the structure of the dataset, the available columns, and the types of data present.
#
# ### 2. **Data Cleaning:**
#    - **Handle Missing Data:** Check for and handle missing values in relevant columns.
#    - **Data Types:** Ensure the data types of columns are appropriate for analysis (e.g., convert 'Installs' and 'Price' columns to numerical data types).
#    - **Duplicates:** Remove duplicate entries if any.
#
# ### 3. **Data Analysis:**
#    - **Popular Categories:** Use the 'Category' column to identify the most common app categories. Create a frequency table to count the number of apps in each category.
#    - **Installations:** Analyze the 'Installs' column to understand the popularity of apps in different categories. Aggregate the number of installs per category to identify popular categories based on user installations.
#    - **Ratings and Reviews:** Consider analyzing user ratings and reviews to gauge user satisfaction for apps in each category. This can provide insights into user engagement.
#    - **Price Range:** Analyze the 'Price' column to understand the pricing strategy in different categories. Identify free or low-cost app categories which might attract more users.
#
# ### 4. **Data Visualization:**
#    - **Bar Charts:** Use bar charts to visually represent the frequency of apps in each category and the number of installs.
#    - **Box Plots:** Visualize the distribution of user ratings for different categories using box plots.
#    - **Scatter Plots:** Create scatter plots to explore the relationship between the number of installs and user ratings for apps in different categories.
#    - **Heatmaps:** Use heatmaps to show correlations between user ratings, number of installs, and app categories.
#
# ### 5. **Statistical Analysis (Optional):**
#    - Consider statistical tests (like ANOVA or t-tests) to compare means of user ratings or number of installs between different categories for more in-depth analysis.
#
# ### 6. **Recommendations:**
#    - **Identify Top Categories:** Based on your analysis, identify the top app categories in terms of popularity, user engagement, and user satisfaction.
#    - **User Preferences:** Provide insights into user preferences, such as preferred price ranges and features.
#    - **Competitor Analysis:** If possible, compare the company's app category preferences with competitors' to identify market gaps or areas of saturation.
#
# ### 7. **Report and Visualization:**
#    - Prepare a report summarizing your findings, including visualizations and key insights.
#    - Use clear and visually appealing charts and graphs to present your recommendations effectively.
#
# By following these steps and conducting a thorough analysis of the Google Play Store dataset, you can provide valuable insights to the company regarding the most popular app categories, enabling them to make informed decisions about their new app launch strategy.

# %% [markdown]
# ### Q16. A mobile app development company wants to analyze the Google Playstore dataset to identify the most successful app developers. What features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?

# %% [markdown]
# To identify the most successful app developers in the Google Play Store dataset, you can focus on analyzing several features that reflect an app's success and the reputation of its developers. Here are the key features to consider and the corresponding data visualizations to present your findings effectively:
#
# ### Features to Analyze:
#
# 1. **Number of Installs:**
#    - Analyze the total number of installs for apps developed by each developer. Developers with higher installation numbers tend to be more successful.
#
# 2. **User Ratings and Reviews:**
#    - Investigate the average user ratings and the number of reviews for apps by each developer. Higher ratings and a significant number of positive reviews indicate user satisfaction.
#
# 3. **App Categories:**
#    - Explore the categories of apps developed by each developer. Some developers might specialize in specific categories, contributing to their success.
#
# 4. **App Pricing:**
#    - Analyze the pricing strategy of apps. Developers offering a mix of free and paid apps might have a successful revenue model.
#
# 5. **App Size:**
#    - Investigate the average size of apps. Some users prefer smaller apps that don't consume much storage space on their devices.
#
# 6. **Update Frequency:**
#    - Consider how frequently developers update their apps. Regular updates often indicate developer engagement and responsiveness to user feedback.
#
# ### Data Visualizations to Use:
#
# 1. **Bar Charts:**
#    - Use bar charts to compare the total number of installs, average ratings, and average number of reviews for each developer.
#    - Display the number of apps developed by each developer in different categories using stacked bar charts.
#
# 2. **Scatter Plots:**
#    - Create scatter plots to visualize the relationship between the number of installs and user ratings for each developer.
#    - Use size and color encoding to represent the number of reviews or app pricing in the scatter plots.
#
# 3. **Box Plots:**
#    - Utilize box plots to show the distribution of user ratings for apps developed by each developer.
#    - Compare the app sizes across different developers using box plots.
#
# 4. **Heatmaps:**
#    - Use heatmaps to represent correlations between app size, user ratings, number of installs, and other numerical features. This can help identify patterns and relationships.
#
# 5. **Pie Charts:**
#    - Use pie charts to show the distribution of apps across different categories for each developer. This can highlight the developer's specialization areas.
#
# 6. **Line Charts:**
#    - Create line charts to visualize the trend in the number of installs or user ratings over time for specific developers. This can indicate their app development trajectory.
#
# 7. **Treemaps:**
#    - Utilize treemaps to represent the hierarchy of app categories and subcategories, providing a clear overview of which categories are more prominent for each developer.
#
# When presenting your findings, focus on clear visualizations and concise explanations. Highlight top developers based on the analyzed metrics, and provide insights into their successful strategies. Visualizations should be labeled appropriately, and any trends or patterns you observe should be clearly communicated to the audience.

# %% [markdown]
# ### Q17. A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to launch a new app. What features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?

# %% [markdown]
# To identify the best time to launch a new app on the Google Play Store, you can analyze various features and user behaviors to make informed recommendations to the marketing research firm. Here are the key features to consider and the corresponding data visualizations to present your findings effectively:
#
# ### Features to Analyze:
#
# 1. **Number of Installs Over Time:**
#    - Analyze the trend in the number of app installs over different months, weeks, or days. Identify peak periods of user activity.
#
# 2. **User Ratings and Reviews Over Time:**
#    - Examine the trend in user ratings and reviews over different time intervals. Determine if certain periods correlate with higher user engagement and positive feedback.
#
# 3. **App Updates Over Time:**
#    - Investigate how frequently successful apps receive updates. A high frequency of updates might indicate continuous improvement and user engagement.
#
# 4. **Competitor Analysis:**
#    - Compare the launch dates and performance of competitor apps. Identify if there are specific times of the year when competitors launch new apps.
#
# 5. **Seasonal Trends:**
#    - Explore if there are seasonal trends or specific events (holidays, festivals) that affect app downloads and user engagement.
#
# 6. **User Demographics and Geography:**
#    - Analyze user demographics and geographic locations to identify regions or demographic groups with higher app engagement during specific periods.
#
# ### Data Visualizations to Use:
#
# 1. **Line Charts:**
#    - Use line charts to display trends in the number of installs, user ratings, and reviews over different time intervals (months, weeks, days).
#    - Highlight specific periods with significant spikes or drops in user activity.
#
# 2. **Bar Charts:**
#    - Utilize bar charts to compare the number of installs, ratings, and reviews for different apps or app categories during specific months or seasons.
#    - Compare the number of app updates across different months or quarters.
#
# 3. **Heatmaps:**
#    - Use heatmaps to represent the distribution of app installs, ratings, or reviews across different days of the week or hours of the day. Identify peak hours or days of user activity.
#
# 4. **Box Plots:**
#    - Create box plots to visualize the distribution of user ratings or app installs during different months or seasons. Identify outliers and overall patterns.
#
# 5. **Stacked Area Charts:**
#    - Use stacked area charts to show the cumulative number of installs or user engagement over different months or weeks. Compare the contributions of different apps or categories.
#
# 6. **Geospatial Maps:**
#    - If geographic data is available, use maps to visualize app installs and user engagement across different regions. Identify regions with high user activity.
#
# 7. **Comparative Charts:**
#    - Use comparative charts (such as grouped bar charts) to compare the performance of your app against competitors' apps over specific time intervals.
#
# When presenting your findings, focus on clear visualizations that highlight trends and patterns over time. Explain any significant findings and provide actionable recommendations based on the analysis. Consider interactive visualizations if you want to allow your audience to explore the data further, especially when dealing with large datasets or complex time-related patterns.
